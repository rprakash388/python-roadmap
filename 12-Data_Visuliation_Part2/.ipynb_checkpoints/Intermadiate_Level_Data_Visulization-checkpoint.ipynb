# %%
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

# %%
mt_cars_data = pd.read_csv("mtcars.csv")

mt_cars_data.head(7)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4

# %% [markdown]
# ## MUST KNOW
#
# Should have the clarity between **Discrete and Continuous Data**

# %% [markdown]
# ## 1. Univariate Analysis
#
# **Important Charts**
#
#  - Histogram
#  - Countplot
#  - Barplot (Not used)
#  - Pie Chart

# %% [markdown]
# #### 1.1 Histogram

# %%
plt.hist(mt_cars_data.mpg)
plt.title("MPG Distribution")
plt.xlabel("MPG")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### 1.2 Countplot

# %%
mt_cars_data.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# #### NOTE:
#
# 1. Matplotlib doesn't have charts which Seaborn has.
# 2. Seaborn will not have some charts which matplotlib has
# 3. Matplotlib and Seaborn will have same charts

# %%
sns.countplot(data=mt_cars_data, x="am", y=None)
plt.title("Automatic Vs Manual Distribution")

plt.show()

# %% [markdown]
# #### 1.3 Barplot

# %%
plt.bar(data=mt_cars_data, x="am", height="mpg")
# Out:
# <BarContainer object of 32 artists>

# %% [markdown]
# #### 1.4 Pie Chart

# %%
mt_cars_data.head(8)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2

# %%
mt_cars_data["cyl"].value_counts()
# Out:
# cyl
# 8    14
# 4    11
# 6     7
# Name: count, dtype: int64

# %%
plt.pie(mt_cars_data["cyl"].value_counts(), labels=["8 Cyl","4 Cyl","6 Cyl"], explode=[0.01, 0.01, 0.01], autopct="%1.0f%%")

plt.figure(figsize=(10,15))
plt.show()

# %% [markdown]
# ## 2. Bivariate Analysis
#
# **Important Charts**
#
#  - Barplot
#  - Scatterplot

# %% [markdown]
# #### 2.1 Barplot

# %%
sns.barplot(data=mt_cars_data, x="am", y="mpg")
# Out:
# <Axes: xlabel='am', ylabel='mpg'>

# %% [markdown]
# #### 2.2 Scatterplot

# %%
mt_cars_data.head(10)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4

# %%
plt.scatter(data=mt_cars_data, x="wt", y="mpg")

plt.show()

# %%
sns.scatterplot(data=mt_cars_data, x="wt", y="mpg")

plt.show()

# %% [markdown]
# ### 3. Multivariate Analysis
#
# **Important Charts**
#
#  - Pairplot
#  - Heatmap

# %%
mt_cars_data.head(10)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4

# %%
sns.pairplot(data=mt_cars_data)

# %%
del mt_cars_data["model"]

# %%
mt_cars_data
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
corr_matrix = mt_cars_data.corr().round(2)

corr_matrix
# Out:
#        mpg   cyl  disp    hp  drat    wt  qsec    vs    am  gear  carb
# mpg   1.00 -0.85 -0.85 -0.78  0.68 -0.87  0.42  0.66  0.60  0.48 -0.55
# cyl  -0.85  1.00  0.90  0.83 -0.70  0.78 -0.59 -0.81 -0.52 -0.49  0.53
# disp -0.85  0.90  1.00  0.79 -0.71  0.89 -0.43 -0.71 -0.59 -0.56  0.39
# hp   -0.78  0.83  0.79  1.00 -0.45  0.66 -0.71 -0.72 -0.24 -0.13  0.75
# drat  0.68 -0.70 -0.71 -0.45  1.00 -0.71  0.09  0.44  0.71  0.70 -0.09
# wt   -0.87  0.78  0.89  0.66 -0.71  1.00 -0.17 -0.55 -0.69 -0.58  0.43
# qsec  0.42 -0.59 -0.43 -0.71  0.09 -0.17  1.00  0.74 -0.23 -0.21 -0.66
# vs    0.66 -0.81 -0.71 -0.72  0.44 -0.55  0.74  1.00  0.17  0.21 -0.57
# am    0.60 -0.52 -0.59 -0.24  0.71 -0.69 -0.23  0.17  1.00  0.79  0.06
# gear  0.48 -0.49 -0.56 -0.13  0.70 -0.58 -0.21  0.21  0.79  1.00  0.27
# carb -0.55  0.53  0.39  0.75 -0.09  0.43 -0.66 -0.57  0.06  0.27  1.00

# %% [markdown]
# #### 3.2 Heapmap

# %%
sns.heatmap(corr_matrix, annot=True)

plt.show()

# %% [markdown]
# ##### NOTES:
#
# - Pearson Correlation and Co-Effiecent
# - Spearson Correlation and Co-Effiecent
#
# E.g -1 to 1

# %% [markdown]
# ##### NOTES:
#
# - 0 to 0.20 = Very Weak Correlation
# - 0.21 to 0.40 = Weak Correlation
# - 0.41 to 0.60 = Normal / Standard Correlation
# - 0.61 to 0.80 = Strong Correlation
# - 0.81 to = Very Strong Correlation

# %% [markdown]
# ## Advanced Level of Data Visulization

# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
fig = px.pie(df, values='pop', names='country', title='Population of European continent')
fig.show()

# %% [markdown]
# ## NOTES:
#
# 1. Univariate charts can include more than one future
# 2. Bivariate charts can include more than 2 features

# %%
sns.histplot(data=mt_cars_data, x="mpg", hue="am", multiple="stack" )
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
import seaborn as sns

import matplotlib.pyplot as plt

penguins = sns.load_dataset("penguins")

sns.histplot(data=penguins, x="flipper_length_mm", kde=True, bins=20, color="skyblue")

plt.title("Flipper Length Distribution with KDE")

plt.show()
