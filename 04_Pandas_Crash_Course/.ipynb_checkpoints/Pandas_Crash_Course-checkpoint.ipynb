# %% [markdown]
# ## Data Analystics Steps
# * Business Understanding
# * Data Collection
# * Data Understanding (Analysis step - Chapter 1)
# * Data Preparation (Data Cleaning - Chapter 2)
# *

# %% [markdown]
# ## Chapter 1: Getting & Knowing your Data

# %%
import pandas as pd

# %%
order_details = pd.read_csv("Orders.csv")
order_details
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %% [markdown]
# ## 1.1 Perform Initial Analysis
# 1. Check if null or empty values
# 2. List down the data types
# 3. Describe the data
# ----
# * Funtion - ()
# * Attribute - Properties

# %%
order_details.shape # returns rows and column count
# Out:
# (9426, 24)

# %% [markdown]
# ### Terminology Alert
# * Row - Observations / Record
# * Column - Features / Parameters

# %%
order_details.isnull().sum() # Chain of functions/commands
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity                 0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
order_details.dtypes
# Out:
# Row ID                    int64
# Order Priority           object
# Discount                float64
# Unit Price              float64
# Shipping Cost           float64
# Customer ID               int64
# Customer Name            object
# Ship Mode                object
# Customer Segment         object
# Product Category         object
# Product Sub-Category     object
# Product Container        object
# Product Name             object
# Product Base Margin     float64
# Region                   object
# State or Province        object
# City                     object
# Postal Code               int64
# Order Date               object
# Ship Date                object
# Profit                  float64
# Quantity                  int64
# Sales                   float64
# Order ID                  int64
# dtype: object

# %%
order_details.describe(include='all')
# Out:
#               Row ID Order Priority     Discount   Unit Price  Shipping Cost  \
# count    9426.000000           9426  9426.000000  9426.000000    9426.000000
# unique           NaN              6          NaN          NaN            NaN
# top              NaN           High          NaN          NaN            NaN
# freq             NaN           1970          NaN          NaN            NaN
# mean    20241.015277            NaN     0.049628    88.303686      12.795142
# std      6101.890965            NaN     0.031798   281.540982      17.181203
# min         2.000000            NaN     0.000000     0.990000       0.490000
# 25%     19330.250000            NaN     0.020000     6.480000       3.192500
# 50%     21686.500000            NaN     0.050000    20.990000       6.050000
# 75%     24042.750000            NaN     0.080000    85.990000      13.990000
# max     26399.000000            NaN     0.250000  6783.020000     164.730000
#
# ...

# %% [markdown]
# ## 1.2 Find out the Items sold in the data

# %%
order_details.nunique() # Find uniquie values for each parameters/columns
# Out:
# Row ID                  9426
# Order Priority             6
# Discount                  16
# Unit Price               751
# Shipping Cost            652
# Customer ID             2703
# Customer Name           2703
# Ship Mode                  3
# Customer Segment           4
# Product Category           3
# Product Sub-Category      17
# Product Container          7
# Product Name            1263
# Product Base Margin       51
# Region                     4
# State or Province         49
# City                    1424
# Postal Code             1697
# Order Date              1419
# Ship Date               1450
# Profit                  8960
# Quantity                 112
# Sales                   8674
# Order ID                6455
# dtype: int64

# %%
print(order_details["Product Name"].unique()) # Find unique values for specific column
# Out:
# ['Avery 49' 'SANFORD Liquid Accent™ Tank-Style Highlighters' 'Xerox 1968'
#  ... 'DAX Wood Document Frame' 'R289LX' 'Alliance Rubber Bands']

# %% [markdown]
# ## 1.3 Read the list of Top 5 Selling Items
# * Groupby Product Name
# * Sum of quantity for each items
# * Descending the list
# * Read the top 5 records

# %%
order_details.groupby(by="Product Name")["Quantity"].sum().sort_values(ascending=False).head(5)
# Out:
# Product Name
# Avery 510                                                                        428
# Executive Impressions 12" Wall Clock                                             409
# US Robotics 56K V.92 Internal PCI Faxmodem                                       398
# Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS                                  393
# Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum    391
# Name: Quantity, dtype: int64

# %% [markdown]
# ## 1.4 Read the list of Least 5 Selling Items
# * Groupby Product Name
# * Sum of quantity for each items
# * Ascending the list
# * Read the top 5 records

# %%
order_details.groupby(by="Product Name")["Quantity"].sum().sort_values(ascending=True).head(5)
# Out:
# Product Name
# Hewlett Packard 610 Color Digital Copier / Printer         1
# APC 7 Outlet Network SurgeArrest Surge Protector           1
# Eldon® Executive Woodline II Desk Accessories, Mahogany    2
# Strathmore #10 Envelopes, Ultimate White                   2
# 14-7/8 x 11 Blue Bar Computer Printout Paper               2
# Name: Quantity, dtype: int64

# %% [markdown]
# ## Chapter 2 - Data Cleaning
# * We should consider numberic data like Int, Float

# %%
order_details
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
order_details.dtypes
# Out:
# Row ID                    int64
# Order Priority           object
# Discount                float64
# Unit Price              float64
# Shipping Cost           float64
# Customer ID               int64
# Customer Name            object
# Ship Mode                object
# Customer Segment         object
# Product Category         object
# Product Sub-Category     object
# Product Container        object
# Product Name             object
# Product Base Margin     float64
# Region                   object
# State or Province        object
# City                     object
# Postal Code               int64
# Order Date               object
# Ship Date                object
# Profit                  float64
# Quantity                  int64
# Sales                   float64
# Order ID                  int64
# Price                    object
# dtype: object

# %%
order_details["Price"].str.replace("₹", "").float()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18936\991945101.py in ?()
# ----> 1 order_details["Price"].str.replace("₹", "").float()
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'float'

# %%
order_details["Price"] = order_details["Price"].str.replace("₹", "").str.replace(",", "").astype(float)

# %%
order_details.dtypes
# Out:
# Row ID                    int64
# Order Priority           object
# Discount                float64
# Unit Price              float64
# Shipping Cost           float64
# Customer ID               int64
# Customer Name            object
# Ship Mode                object
# Customer Segment         object
# Product Category         object
# Product Sub-Category     object
# Product Container        object
# Product Name             object
# Product Base Margin     float64
# Region                   object
# State or Province        object
# City                     object
# Postal Code               int64
# Order Date               object
# Ship Date                object
# Profit                  float64
# Quantity                  int64
# Sales                   float64
# Order ID                  int64
# Price                   float64
# dtype: object

# %%
order_details.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
#
#        Product Base Margin   Postal Code        Profit     Quantity  \
# count          9354.000000   9426.000000   9426.000000  9426.000000
# mean              0.512189  52446.327286    139.236410    13.798430
# std               0.135229  29374.597802    998.486483    15.107688
# ...

# %% [markdown]
# ## Tasks
# 1. Find out the Top 5 Selling Items individual Revenue it made
# 2. Total Revenue of the Top 5 Items Sold

# %%
order_details.groupby(by="Product Name")["Quantity"].sum().sort_values(ascending=False).head(5)
# Out:
# Product Name
# Avery 510                                                                        428
# Executive Impressions 12" Wall Clock                                             409
# US Robotics 56K V.92 Internal PCI Faxmodem                                       398
# Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS                                  393
# Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum    391
# Name: Quantity, dtype: int64

# %%
order_details.groupby(by="Product Name")["Price"].sum().sort_values(ascending=False).head(5)
# Out:
# Product Name
# Global Troy™ Executive Leather Low-Back Tilter                   195382.20
# Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish    192934.62
# Bretford CR8500 Series Meeting Room Furniture                    111478.20
# Hewlett-Packard cp1700 [D, PS] Series Color Inkjet Printers      107209.72
# Canon PC1080F Personal Copier                                    106198.23
# Name: Price, dtype: float64

# %% [markdown]
# ## Chapter 3 - Pandas Data Structure
# * 1 Dimesional Data - Call it as Series
# * 2 Dimesional Data - DataFrame

# %%
pd.Series(data=[11,23,56.7, '$23.6']) # It allows only 1D
# Out:
# 0       11
# 1       23
# 2     56.7
# 3    $23.6
# dtype: object

# %%
pd.DataFrame(data=[11,23,56.7, '$23.6'])
# Out:
#        0
# 0     11
# 1     23
# 2   56.7
# 3  $23.6

# %%
pd.DataFrame({
            "Name":["Prakash Raju", "Sharmila P", "Divaydharshana S P", "Gokulakannan S P"],
            "English": [60, 90, 95, 80],
              "Maths": [89, 95, 100, 92]
        })
# Out:
#                  Name  English  Maths
# 0        Prakash Raju       60     89
# 1          Sharmila P       90     95
# 2  Divaydharshana S P       95    100
# 3    Gokulakannan S P       80     92

# %% [markdown]
# ### Tasks
# 1. Create a meaningful Series
# 2. Create a meaningful Dataset using Pandas with Dict 5 Observation across 6 Features

# %%
tuple_data=(34,67,23,68,89,23,78,56,85,95,35,78)
tuple_data
# Out:
# (34, 67, 23, 68, 89, 23, 78, 56, 85, 95, 35, 78)

# %%
pd.Series(tuple_data)
# Out:
# 0     34
# 1     67
# 2     23
# 3     68
# 4     89
# 5     23
# 6     78
# 7     56
# 8     85
# 9     95
# 10    35
# 11    78
# dtype: int64

# %%
dic_data={
            "EmployeeId": ["EMP001", "CON002", "EMP005", "EMP008", "CON005", "EMP006"],
            "EmployeeName": ["Prakash R", "Sharmila P", "Divyadharshana S P", "Gokulakannan S P", "Kamala R", "Raju M"],
            "Salary": [35000, 42000, 56000, 85000, 55000, 75000],
            "Department": ["Developer", "Tester", "DevOps Engineer", "Lead Developer", "AI Developer", "AI Architect"],
            "Sex": ["Male", "Female", "Female", "Male", "Female", "Male"]
        }

# %%
pd.DataFrame(dic_data)
# Out:
#   EmployeeId        EmployeeName  Salary       Department     Sex
# 0     EMP001           Prakash R   35000        Developer    Male
# 1     CON002          Sharmila P   42000           Tester  Female
# 2     EMP005  Divyadharshana S P   56000  DevOps Engineer  Female
# 3     EMP008    Gokulakannan S P   85000   Lead Developer    Male
# 4     CON005            Kamala R   55000     AI Developer  Female
# 5     EMP006              Raju M   75000     AI Architect    Male

# %% [markdown]
# ## Chapter 4 - Filtering, Selection and Sorting

# %%
euro_2012_data = pd.read_csv("Euro 2012 stats TEAM.csv")
euro_2012_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_2012_data.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
euro_2012_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
pd.set_option('display.max_columns', None) # Shows all columns

# %%
filtered_euro_data = euro_2012_data[["Team", "Goals", "Yellow Cards", "Red Cards"]] 
# Selections - "Team", "Goals", "Yellow Cards", "Red Cards"
filtered_euro_data
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0
# 2               Denmark      4             4          0
# 3               England      5             5          0
# 4                France      3             6          0
# 5               Germany     10             4          0
# 6                Greece      5             9          1
# 7                 Italy      6            16          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 10             Portugal      6            12          0
# 11  Republic of Ireland      1             6          1
# 12               Russia      5             6          0
# 13                Spain     12            11          0
# 14               Sweden      5             7          0
# 15              Ukraine      2             5          0

# %%
filtered_euro_data1=filtered_euro_data.filter(items=["Team", "Goals", "Yellow Cards", "Red Cards"])
filtered_euro_data1
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0
# 2               Denmark      4             4          0
# 3               England      5             5          0
# 4                France      3             6          0
# 5               Germany     10             4          0
# 6                Greece      5             9          1
# 7                 Italy      6            16          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 10             Portugal      6            12          0
# 11  Republic of Ireland      1             6          1
# 12               Russia      5             6          0
# 13                Spain     12            11          0
# 14               Sweden      5             7          0
# 15              Ukraine      2             5          0

# %%
filtered_euro_data.sort_values(by="Yellow Cards",ascending=False).head(5)
# Out:
#         Team  Goals  Yellow Cards  Red Cards
# 7      Italy      6            16          0
# 10  Portugal      6            12          0
# 13     Spain     12            11          0
# 0    Croatia      4             9          0
# 6     Greece      5             9          1

# %%
filtered_euro_data["Red Cards"] == 1
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# Name: Red Cards, dtype: bool

# %%
filtered_euro_data[filtered_euro_data["Red Cards"] == 1]
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 6                Greece      5             9          1
# 9                Poland      2             7          1
# 11  Republic of Ireland      1             6          1

# %%
filtered_euro_data[filtered_euro_data["Yellow Cards"] >= 8]
# Out:
#         Team  Goals  Yellow Cards  Red Cards
# 0    Croatia      4             9          0
# 6     Greece      5             9          1
# 7      Italy      6            16          0
# 10  Portugal      6            12          0
# 13     Spain     12            11          0

# %% [markdown]
# ## Chapter 5 - Handling Missing Data

# %%
emplyees = pd.read_csv("employees.csv")
emplyees
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME  PHONE_NUMBER  HIRE_DATE   SALARY  \
# 0           198       Donald     OConnell  650.507.9833  21-Jun-07   2600.0
# 1           199      Douglas        Grant  650.507.9844  13-Jan-08   2600.0
# 2           200     Jennifer       Whalen  515.123.4444  17-Sep-03   4400.0
# 3           201      Michael    Hartstein  515.123.5555  17-Feb-04      NaN
# 4           202          Pat          Fay  603.123.6666  17-Aug-05   6000.0
# 5           203          NaN          NaN  515.123.7777  07-Jun-02   6500.0
# 6           204      Hermann         Baer  515.123.8888  07-Jun-02  10000.0
# 7           205      Shelley      Higgins  515.123.8080  07-Jun-02  12008.0
# 8           206      William        Gietz  515.123.8181  07-Jun-02   8300.0
# 9           100       Steven         King  515.123.4567  17-Jun-03  24000.0
# 10          101        Neena      Kochhar  515.123.4568  21-Sep-05  17000.0
# ...

# %% [markdown]
# ### Level 1 - Understanding the excel data, identifying the missing/incorrect data, connect with Client to validate it
#
# In case, the Client is asking to proceed with the same data

# %% [markdown]
# #### Step 1 - Remove duplicate records

# %%
emplyees.drop_duplicates(inplace=True) # Remove duplicates and store it in same name
emplyees
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME  PHONE_NUMBER  HIRE_DATE   SALARY  \
# 0           198       Donald     OConnell  650.507.9833  21-Jun-07   2600.0
# 1           199      Douglas        Grant  650.507.9844  13-Jan-08   2600.0
# 2           200     Jennifer       Whalen  515.123.4444  17-Sep-03   4400.0
# 3           201      Michael    Hartstein  515.123.5555  17-Feb-04      NaN
# 4           202          Pat          Fay  603.123.6666  17-Aug-05   6000.0
# 5           203          NaN          NaN  515.123.7777  07-Jun-02   6500.0
# 6           204      Hermann         Baer  515.123.8888  07-Jun-02  10000.0
# 7           205      Shelley      Higgins  515.123.8080  07-Jun-02  12008.0
# 8           206      William        Gietz  515.123.8181  07-Jun-02   8300.0
# 9           100       Steven         King  515.123.4567  17-Jun-03  24000.0
# 10          101        Neena      Kochhar  515.123.4568  21-Sep-05  17000.0
# ...

# %% [markdown]
# #### Step 2: Find out Null records

# %%
emplyees.isnull().sum()
# Out:
# EMPLOYEE_ID     0
# FIRST_NAME      6
# LAST_NAME       6
# PHONE_NUMBER    0
# HIRE_DATE       0
# SALARY          4
# MANAGER_ID      2
# ROLE            0
# dtype: int64

# %% [markdown]
# #### Step 3 - Record a document
#
# * Client gave 49 records out of which 16 records are removed because those records do not have complete information

# %%
emplyees.dropna(inplace=True)
emplyees
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME  PHONE_NUMBER  HIRE_DATE   SALARY  \
# 0           198       Donald     OConnell  650.507.9833  21-Jun-07   2600.0
# 1           199      Douglas        Grant  650.507.9844  13-Jan-08   2600.0
# 2           200     Jennifer       Whalen  515.123.4444  17-Sep-03   4400.0
# 4           202          Pat          Fay  603.123.6666  17-Aug-05   6000.0
# 6           204      Hermann         Baer  515.123.8888  07-Jun-02  10000.0
# 7           205      Shelley      Higgins  515.123.8080  07-Jun-02  12008.0
# 8           206      William        Gietz  515.123.8181  07-Jun-02   8300.0
# 10          101        Neena      Kochhar  515.123.4568  21-Sep-05  17000.0
# 11          102          Lex      De Haan  515.123.4569  13-Jan-01  17000.0
# 12          103    Alexander       Hunold  590.423.4567  03-Jan-06   9000.0
# 13          104        Bruce        Ernst  590.423.4568  21-May-07   6000.0
# ...

# %%
emplyees.shape
# Out:
# (38, 8)

# %% [markdown]
# #### Step 4: Get Approval
# * Send this to Client and get the approval to proceed for Model Building or Training

# %%
emplyees.isnull().sum()
# Out:
# EMPLOYEE_ID     0
# FIRST_NAME      0
# LAST_NAME       0
# PHONE_NUMBER    0
# HIRE_DATE       0
# SALARY          0
# MANAGER_ID      0
# ROLE            0
# dtype: int64

# %% [markdown]
# ## Level 2 - Data Cleaning

# %%
employee_data=pd.read_csv("employees.csv")
employee_data
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME  PHONE_NUMBER  HIRE_DATE   SALARY  \
# 0           198       Donald     OConnell  650.507.9833  21-Jun-07   2600.0
# 1           199      Douglas        Grant  650.507.9844  13-Jan-08   2600.0
# 2           200     Jennifer       Whalen  515.123.4444  17-Sep-03   4400.0
# 3           201      Michael    Hartstein  515.123.5555  17-Feb-04      NaN
# 4           202          Pat          Fay  603.123.6666  17-Aug-05   6000.0
# 5           203          NaN          NaN  515.123.7777  07-Jun-02   6500.0
# 6           204      Hermann         Baer  515.123.8888  07-Jun-02  10000.0
# 7           205      Shelley      Higgins  515.123.8080  07-Jun-02  12008.0
# 8           206      William        Gietz  515.123.8181  07-Jun-02   8300.0
# 9           100       Steven         King  515.123.4567  17-Jun-03  24000.0
# 10          101        Neena      Kochhar  515.123.4568  21-Sep-05  17000.0
# ...

# %%
employee_data.duplicated() # Find out the duplicate entries
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %% [markdown]
# #### Step 4.1 Drop / Remove the duplicate entries

# %%
employee_data.drop_duplicates(inplace=True)
employee_data
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME  PHONE_NUMBER  HIRE_DATE   SALARY  \
# 0           198       Donald     OConnell  650.507.9833  21-Jun-07   2600.0
# 1           199      Douglas        Grant  650.507.9844  13-Jan-08   2600.0
# 2           200     Jennifer       Whalen  515.123.4444  17-Sep-03   4400.0
# 3           201      Michael    Hartstein  515.123.5555  17-Feb-04      NaN
# 4           202          Pat          Fay  603.123.6666  17-Aug-05   6000.0
# 5           203          NaN          NaN  515.123.7777  07-Jun-02   6500.0
# 6           204      Hermann         Baer  515.123.8888  07-Jun-02  10000.0
# 7           205      Shelley      Higgins  515.123.8080  07-Jun-02  12008.0
# 8           206      William        Gietz  515.123.8181  07-Jun-02   8300.0
# 9           100       Steven         King  515.123.4567  17-Jun-03  24000.0
# 10          101        Neena      Kochhar  515.123.4568  21-Sep-05  17000.0
# ...

# %% [markdown]
# #### Step 4.2 - Identify the Null entries

# %%
employee_data.isna().sum()
# Out:
# EMPLOYEE_ID     0
# FIRST_NAME      6
# LAST_NAME       6
# PHONE_NUMBER    0
# HIRE_DATE       0
# SALARY          4
# MANAGER_ID      2
# ROLE            0
# dtype: int64

# %% [markdown]
# #### Step 4.3 - Go for best Imputation

# %%
employee_data["ROLE"].unique()
# Out:
# array(['DevOps', 'Developer', 'Tester', 'Lead Developer', 'AI Developer',
#        'AI Architect'], dtype=object)

# %% [markdown]
# ##### 4.3.1 Data Analtstics

# %%
employee_data[employee_data["ROLE"] == "DevOps"]
# Out:
#     EMPLOYEE_ID   FIRST_NAME LAST_NAME  PHONE_NUMBER  HIRE_DATE  SALARY  \
# 0           198       Donald  OConnell  650.507.9833  21-Jun-07  2600.0
# 8           206      William     Gietz  515.123.8181  07-Jun-02  8300.0
# 21          112  Jose Manuel     Urman  515.124.4469  07-Mar-06  7800.0
# 29          120      Matthew     Weiss  650.123.1234  18-Jul-04  8000.0
# 30          121         Adam     Fripp  650.123.2234  10-Apr-05  8200.0
# 34          125        Julia     Nayer  650.124.1214  16-Jul-05  3200.0
# 41          132           TJ     Olson  650.124.8234  10-Apr-07  2100.0
# 47          138          NaN       NaN  650.121.2034  26-Oct-05  3200.0
#
#     MANAGER_ID    ROLE
# 0        124.0  DevOps
# 8        205.0  DevOps
# 21       108.0  DevOps
# 29       100.0  DevOps
# 30       100.0  DevOps
# 34       120.0  DevOps
# 41       121.0  DevOps
# 47       123.0  DevOps

# %%
employee_data[employee_data["ROLE"] == "Developer"]
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME  PHONE_NUMBER  HIRE_DATE   SALARY  \
# 1           199    Douglas      Grant  650.507.9844  13-Jan-08   2600.0
# 5           203        NaN        NaN  515.123.7777  07-Jun-02   6500.0
# 13          104      Bruce      Ernst  590.423.4568  21-May-07   6000.0
# 16          107        NaN        NaN  590.423.5567  07-Feb-07   4200.0
# 17          108      Nancy  Greenberg  515.124.4569  17-Aug-02  12008.0
# 19          110       John       Chen  515.124.4269  28-Sep-05   8200.0
# 20          111     Ismael    Sciarra  515.124.4369  30-Sep-05   7700.0
# 26          117      Sigal     Tobias  515.127.4564  24-Jul-05   2800.0
# 31          122      Payam   Kaufling  650.123.3234  01-May-03   7900.0
# 36          127      James     Landry  650.124.1334  14-Jan-07   2400.0
# 38          129      Laura     Bissot  650.124.5234  20-Aug-05   3300.0
# 42          133      Jason     Mallin  650.127.1934  14-Jun-04   3300.0
# ...

# %%
employee_data[employee_data["ROLE"] == "Tester"]
# Out:
#     EMPLOYEE_ID FIRST_NAME    LAST_NAME  PHONE_NUMBER  HIRE_DATE   SALARY  \
# 2           200   Jennifer       Whalen  515.123.4444  17-Sep-03   4400.0
# 7           205    Shelley      Higgins  515.123.8080  07-Jun-02  12008.0
# 12          103  Alexander       Hunold  590.423.4567  03-Jan-06   9000.0
# 24          115  Alexander         Khoo  515.127.4562  18-May-03   3100.0
# 35          126      Irene  Mikkilineni  650.124.1224  28-Sep-06   2700.0
# 45          136      Hazel   Philtanker  650.127.1634  06-Feb-08   2200.0
#
#     MANAGER_ID    ROLE
# 2        101.0  Tester
# 7        101.0  Tester
# 12       102.0  Tester
# 24       114.0  Tester
# 35       120.0  Tester
# 45       122.0  Tester

# %%
employee_data[employee_data["ROLE"] == "Lead Developer"]
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME  PHONE_NUMBER  HIRE_DATE   SALARY  \
# 3           201    Michael  Hartstein  515.123.5555  17-Feb-04      NaN
# 9           100     Steven       King  515.123.4567  17-Jun-03  24000.0
# 11          102        Lex    De Haan  515.123.4569  13-Jan-01  17000.0
# 23          114        Den   Raphaely  515.127.4561  07-Dec-02  11000.0
# 25          116        NaN        NaN  515.127.4563  24-Dec-05   2900.0
# 39          130      Mozhe   Atkinson  650.124.6234  30-Oct-05   2800.0
#
#     MANAGER_ID            ROLE
# 3        100.0  Lead Developer
# 9          NaN  Lead Developer
# 11       100.0  Lead Developer
# 23       100.0  Lead Developer
# 25       114.0  Lead Developer
# 39       121.0  Lead Developer

# %%
employee_data[employee_data["ROLE"] == "AI Developer"]
# Out:
#     EMPLOYEE_ID FIRST_NAME   LAST_NAME  PHONE_NUMBER  HIRE_DATE   SALARY  \
# 4           202        Pat         Fay  603.123.6666  17-Aug-05   6000.0
# 10          101      Neena     Kochhar  515.123.4568  21-Sep-05  17000.0
# 15          106      Valli   Pataballa  590.423.4560  05-Feb-06   4800.0
# 27          118        Guy      Himuro  515.127.4565  15-Nov-06   2600.0
# 28          119      Karen  Colmenares  515.127.4566  10-Aug-07      NaN
# 32          123        NaN         NaN  650.123.4234  10-Oct-05   6500.0
# 33          124      Kevin     Mourgos  650.123.5234  16-Nov-07   5800.0
# 37          128     Steven      Markle  650.124.1434  08-Mar-08   2200.0
# 40          131        NaN         NaN  650.124.7234  16-Feb-05   2500.0
#
#     MANAGER_ID          ROLE
# 4        201.0  AI Developer
# 10       100.0  AI Developer
# 15       103.0  AI Developer
# 27       114.0  AI Developer
# 28       114.0  AI Developer
# 32       100.0  AI Developer
# ...

# %%
employee_data[employee_data["ROLE"] == "AI Architect"]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME  PHONE_NUMBER  HIRE_DATE   SALARY  \
# 6           204    Hermann      Baer  515.123.8888  07-Jun-02  10000.0
# 14          105      David    Austin  590.423.4569  25-Jun-05      NaN
# 18          109     Daniel    Faviet  515.124.4169  16-Aug-02   9000.0
# 22          113       Luis      Popp  515.124.4567  07-Dec-07   6900.0
# 44          135         Ki       Gee  650.127.1734  12-Dec-07   2400.0
# 48          139       John       Seo  650.121.2019  12-Feb-06   2700.0
#
#     MANAGER_ID          ROLE
# 6        101.0  AI Architect
# 14       103.0  AI Architect
# 18       108.0  AI Architect
# 22       108.0  AI Architect
# 44       122.0  AI Architect
# 48       123.0  AI Architect

# %% [markdown]
# #### Data Analytics Task
# 1. Impute the relevant values in the Salary Coulmn whether it is NaN, based on Department Filtering.
# 2. Impute the relevant ages

# %%
employee_data[(employee_data["ROLE"] == "AI Architect") & (employee_data["SALARY"].isna())]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME  PHONE_NUMBER  HIRE_DATE  SALARY  \
# 14          105      David    Austin  590.423.4569  25-Jun-05     NaN
#
#     MANAGER_ID          ROLE
# 14       103.0  AI Architect

# %%
employee_105 = employee_data[(employee_data["EMPLOYEE_ID"]) == 105]
employee_105
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME  PHONE_NUMBER  HIRE_DATE  SALARY  \
# 14          105      David    Austin  590.423.4569  25-Jun-05     NaN
#
#     MANAGER_ID          ROLE
# 14       103.0  AI Architect

# %%
employee_105["SALARY"] = employee_105["SALARY"].fillna(9999)

employee_105
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_26984\2753165524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   employee_105["SALARY"] = employee_105["SALARY"].fillna(9999)
#     EMPLOYEE_ID FIRST_NAME LAST_NAME PHONE_NUMBER HIRE_DATE  SALARY  \
# 14         9999       9999      9999         9999      9999  9999.0
#
#     MANAGER_ID  ROLE
# 14      9999.0  9999

# %%
employee_105.loc[employee_105["SALARY"].isnull(), "SALARY"] = (
    employee_105.loc[employee_105["SALARY"].isnull(), "SALARY"].fillna(9999)
)

employee_105
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME  PHONE_NUMBER  HIRE_DATE  SALARY  \
# 14          105      David    Austin  590.423.4569  25-Jun-05  9999.0
#
#     MANAGER_ID          ROLE
# 14       103.0  AI Architect
