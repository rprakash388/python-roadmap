# %% [markdown]
# ## 1. Import required libraries

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp310-cp310-win_amd64.whl (8.9 MB)
#      ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#      ---------------------------------------- 0.1/8.9 MB 1.5 MB/s eta 0:00:06
#      - -------------------------------------- 0.2/8.9 MB 1.9 MB/s eta 0:00:05
#      --- ------------------------------------ 0.8/8.9 MB 4.4 MB/s eta 0:00:02
#      ------ --------------------------------- 1.4/8.9 MB 6.4 MB/s eta 0:00:02
#      ---------- ----------------------------- 2.2/8.9 MB 8.3 MB/s eta 0:00:01
#      -------------- ------------------------- 3.2/8.9 MB 10.1 MB/s eta 0:00:01
#      ------------------- -------------------- 4.2/8.9 MB 11.8 MB/s eta 0:00:01
#      ------------------------- -------------- 5.7/8.9 MB 14.0 MB/s eta 0:00:01
#      -------------------------------- ------- 7.2/8.9 MB 15.9 MB/s eta 0:00:01
#      ---------------------------------------  8.9/8.9 MB 17.7 MB/s eta 0:00:01
#      ---------------------------------------  8.9/8.9 MB 17.7 MB/s eta 0:00:01
#      ---------------------------------------- 8.9/8.9 MB 15.8 MB/s eta 0:00:00
# Collecting scipy>=1.8.0
#   Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
#      ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#      - -------------------------------------- 1.7/41.3 MB 35.9 MB/s eta 0:00:02
#      --- ------------------------------------ 3.5/41.3 MB 37.6 MB/s eta 0:00:02
#      ----- ---------------------------------- 5.3/41.3 MB 37.7 MB/s eta 0:00:01
#      ------ --------------------------------- 7.2/41.3 MB 38.2 MB/s eta 0:00:01
#      -------- ------------------------------- 8.9/41.3 MB 40.6 MB/s eta 0:00:01
#      --------- ------------------------------ 9.5/41.3 MB 35.8 MB/s eta 0:00:01
#      ---------- ---------------------------- 11.6/41.3 MB 34.4 MB/s eta 0:00:01
#      ----------- --------------------------- 12.6/41.3 MB 34.4 MB/s eta 0:00:01
#      ------------ -------------------------- 13.7/41.3 MB 32.7 MB/s eta 0:00:01
#      -------------- ------------------------ 14.9/41.3 MB 29.7 MB/s eta 0:00:01
#      --------------- ----------------------- 16.0/41.3 MB 28.5 MB/s eta 0:00:01
#      ---------------- ---------------------- 17.2/41.3 MB 27.3 MB/s eta 0:00:01
#      ----------------- --------------------- 18.3/41.3 MB 26.2 MB/s eta 0:00:01
#      ------------------ -------------------- 19.5/41.3 MB 26.2 MB/s eta 0:00:01
#      ------------------- ------------------- 20.7/41.3 MB 26.2 MB/s eta 0:00:01
#      -------------------- ------------------ 22.0/41.3 MB 25.2 MB/s eta 0:00:01
#      --------------------- ----------------- 23.2/41.3 MB 27.3 MB/s eta 0:00:01
#      ----------------------- --------------- 24.4/41.3 MB 26.2 MB/s eta 0:00:01
#      ------------------------ -------------- 25.7/41.3 MB 26.2 MB/s eta 0:00:01
#      ------------------------- ------------- 26.9/41.3 MB 26.2 MB/s eta 0:00:01
#      -------------------------- ------------ 28.3/41.3 MB 27.3 MB/s eta 0:00:01
#      --------------------------- ----------- 29.5/41.3 MB 27.3 MB/s eta 0:00:01
#      ----------------------------- --------- 30.9/41.3 MB 27.3 MB/s eta 0:00:01
#      ------------------------------ -------- 32.2/41.3 MB 27.3 MB/s eta 0:00:01
#      ------------------------------- ------- 33.3/41.3 MB 27.3 MB/s eta 0:00:01
#      -------------------------------- ------ 34.6/41.3 MB 27.3 MB/s eta 0:00:01
#      --------------------------------- ----- 35.9/41.3 MB 27.3 MB/s eta 0:00:01
#      ----------------------------------- --- 37.1/41.3 MB 27.3 MB/s eta 0:00:01
#      ------------------------------------ -- 38.3/41.3 MB 27.3 MB/s eta 0:00:01
#      ------------------------------------- - 39.7/41.3 MB 27.3 MB/s eta 0:00:01
#      --------------------------------------  40.9/41.3 MB 27.3 MB/s eta 0:00:01
#      --------------------------------------  41.3/41.3 MB 27.3 MB/s eta 0:00:01
#      --------------------------------------  41.3/41.3 MB 27.3 MB/s eta 0:00:01
#      --------------------------------------  41.3/41.3 MB 27.3 MB/s eta 0:00:01
#      --------------------------------------  41.3/41.3 MB 27.3 MB/s eta 0:00:01
#      --------------------------------------  41.3/41.3 MB 27.3 MB/s eta 0:00:01
#      --------------------------------------  41.3/41.3 MB 27.3 MB/s eta 0:00:01
#      --------------------------------------- 41.3/41.3 MB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.0 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (2.2.6)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.6.0-py3-none-any.whl (306 kB)
#      ---------------------------------------- 0.0/306.1 kB ? eta -:--:--
#      ------------------------------------- 306.1/306.1 kB 19.7 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting cloudpickle>=3.0
#   Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Installing collected packages: threadpoolctl, scipy, cloudpickle, joblib, scikit-learn
# Successfully installed cloudpickle-3.1.2 joblib-1.6.0 scikit-learn-1.7.2 scipy-1.15.3 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from  matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

import warnings
warnings.filterwarnings(action="ignore")

# %% [markdown]
# ## 2. Import Dataset

# %%
cars_data = pd.read_csv(filepath_or_buffer="Cars.csv")

cars_data
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %% [markdown]
# ## 3. Data Understanding

# %% [markdown]
# ### 3.1 Perform Initial Investigation on the data

# %%
cars_data.shape
# Out:
# (81, 5)

# %%
cars_data.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars_data.dtypes
# Out:
# HP       int64
# MPG    float64
# VOL      int64
# SP     float64
# WT     float64
# dtype: object

# %%
cars_data.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %% [markdown]
# ## Now, let's check for the Assuptions

# %% [markdown]
# ### 1. Linearity Test

# %%
sns.lmplot(cars_data, x="HP", y="MPG")

# %%
sns.lmplot(cars_data, x="VOL", y="MPG")

# %%
sns.lmplot(cars_data, x="SP", y="MPG")

# %%
sns.lmplot(cars_data, x="WT", y="MPG")

# %% [markdown]
# #### Test 1 - Linearity Failed

# %% [markdown]
# ### 2. Normality Test

# %%
plt.hist(cars_data["HP"])
# Out:
# (array([15., 35.,  9.,  6.,  9.,  0.,  2.,  2.,  1.,  2.]),
#  array([ 49. ,  76.3, 103.6, 130.9, 158.2, 185.5, 212.8, 240.1, 267.4,
#         294.7, 322. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(x=cars_data["HP"])
# Out:
# <Axes: ylabel='Density'>

# %%
plt.hist(cars_data["SP"])
# Out:
# (array([ 8., 12., 32., 10., 10.,  2.,  1.,  2.,  1.,  3.]),
#  array([ 99.56490661, 106.56826723, 113.57162785, 120.57498847,
#         127.57834909, 134.58170971, 141.58507032, 148.58843094,
#         155.59179156, 162.59515218, 169.5985128 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(cars_data["VOL"])
# Out:
# (array([ 9.,  0.,  0., 22., 20., 15.,  8.,  6.,  0.,  1.]),
#  array([ 50.,  61.,  72.,  83.,  94., 105., 116., 127., 138., 149., 160.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(cars_data["WT"])
# Out:
# (array([ 9.,  0.,  0., 22., 19., 18.,  7.,  5.,  0.,  1.]),
#  array([15.71285853, 19.44134791, 23.1698373 , 26.89832668, 30.62681606,
#         34.35530544, 38.08379483, 41.81228421, 45.54077359, 49.26926298,
#         52.99775236]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Test 2 Normality also Failed

# %% [markdown]
# ### 3. Multi-Collinearity Test

# %%
corr_matrix = cars_data.corr("pearson")
corr_matrix
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.heatmap(data=corr_matrix, annot=True)
plt.show()

# %% [markdown]
# #### Test 3 - There is Multi Collinearity in the data

# %% [markdown]
# ### 4. Auto Regression Test Passed
#
# There is no DateTime Input features/parameters in the data
#
#  - **Input Coulmns** are HP, VOL, SP, WT
#  - **Output Column** is MPG

# %% [markdown]
# ### Test 5 and 6 - Can be done only after Model is Built, Trained and Tested (Refer Point #8)

# %% [markdown]
# ## 4. Data Preparation

# %%
cars_data
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
x = cars_data[["HP", "VOL", "SP", "WT"]]

y = cars_data["MPG"]

y
# Out:
# 0     53.700681
# 1     50.013401
# 2     50.013401
# 3     45.696322
# 4     50.504232
#         ...
# 76    36.900000
# 77    19.197888
# 78    34.000000
# 79    19.833733
# 80    12.101263
# Name: MPG, Length: 81, dtype: float64

# %% [markdown]
# ### There is nothing to prepare because all features are numeric values

# %% [markdown]
# ## 5. Model Building

# %%
linear_model = LinearRegression()

# %% [markdown]
# ## 6. Model Training

# %%
linear_model.fit(x,y)
# Out:
# LinearRegression()

# %%
linear_model.intercept_
# Out:
# np.float64(30.67733585215165)

# %%
linear_model.coef_
# Out:
# array([-0.20544372, -0.33605084,  0.39562692,  0.40057409])

# %% [markdown]
# ## 7. Model Testing

# %%
y_pred = linear_model.predict(x)

y_pred
# Out:
# array([43.44193477, 42.38879289, 42.27934147, 42.53835981, 42.17264802,
#        43.02061916, 42.32536062, 48.07621852, 48.28120247, 40.79122814,
#        41.52153227, 47.80956747, 39.95980269, 41.52757889, 41.76632332,
#        41.6181448 , 41.15094046, 47.98605515, 41.30861046, 37.87127922,
#        38.57706414, 37.35199705, 37.89770285, 39.5625144 , 39.93380662,
#        46.73870908, 35.48165898, 38.78152504, 38.24861192, 36.00285298,
#        34.84603989, 37.21630246, 37.13919796, 34.82541399, 37.22361389,
#        37.53950097, 39.27144845, 38.24219888, 38.54286458, 35.9391722 ,
#        34.2129755 , 35.36313259, 37.50473376, 38.07998482, 35.79651664,
#        36.2613377 , 34.21826465, 35.59393404, 36.91805291, 33.31108154,
#        33.21313413, 33.3023649 , 29.19864884, 27.52358579, 28.3207133 ,
#        28.56722621, 35.81583602, 33.02108459, 35.37334971, 32.29909503,
#        29.87685849, 28.76093817, 25.14188416, 26.47040896, 25.97651933,
#        36.35652478, 26.0975912 , 23.6416178 , 24.39887199, 20.21195358,
#        27.80846468, 22.44206834, 23.07667801, 18.717314  , 23.84934696,
#        21.07461275, 21.28209598, 17.89904991, 26.13645315, 12.31661154,
#        15.55948057])

# %% [markdown]
# ## 8. Model Evaluation

# %%
error = y-y_pred

error
# Out:
# 0     10.258747
# 1      7.624608
# 2      7.734060
# 3      3.157963
# 4      8.331584
#         ...
# 76    15.617904
# 77     1.298838
# 78     7.863547
# 79     7.517122
# 80    -3.458218
# Name: MPG, Length: 81, dtype: float64

# %%
error.mean()
# Out:
# np.float64(3.50885301609926e-16)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score

# %%
mean_absolute_error(y, y_pred) # same units
# Out:
# 3.267968285420799

# %%
mean_squared_error(y, y_pred) # squared output units
# Out:
# 18.8971411523431

# %%
root_mean_squared_error(y, y_pred) # normalize units
# Out:
# 4.347084212704315

# %%
r2_score(y, y_pred)
# Out:
# 0.7705372737359844

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (0.15.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (26.3)
# Requirement already satisfied: formulaic>=1.1.0 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (1.2.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: numpy<3,>=1.23.5 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (2.2.6)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (1.0.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from formulaic>=1.1.0->statsmodels) (4.16.0)
# Requirement already satisfied: narwhals>=1.17 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from formulaic>=1.1.0->statsmodels) (2.24.0)
# Requirement already satisfied: wrapt>=1.0 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from formulaic>=1.1.0->statsmodels) (2.4.1)
# Requirement already satisfied: interface-meta>=1.2.0 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from formulaic>=1.1.0->statsmodels) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip uninstall statsmodels -y
# !{sys.executable} -m pip install --upgrade statsmodels
# Out:
# Found existing installation: statsmodels 0.15.0
# Uninstalling statsmodels-0.15.0:
#   Successfully uninstalled statsmodels-0.15.0
# Collecting statsmodels
#   Using cached statsmodels-0.15.0-cp310-cp310-win_amd64.whl (11.4 MB)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: numpy<3,>=1.23.5 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (2.2.6)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (1.0.3)
# Requirement already satisfied: formulaic>=1.1.0 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (1.2.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (26.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from formulaic>=1.1.0->statsmodels) (4.16.0)
# Requirement already satisfied: interface-meta>=1.2.0 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from formulaic>=1.1.0->statsmodels) (2.0.1)
# Requirement already satisfied: narwhals>=1.17 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from formulaic>=1.1.0->statsmodels) (2.24.0)
# Requirement already satisfied: wrapt>=1.0 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from formulaic>=1.1.0->statsmodels) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Installing collected packages: statsmodels
# Successfully installed statsmodels-0.15.0
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import statsmodels.formula.api as smf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import statsmodels.formula.api as smf
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\formula\api.py:10
#       8 import statsmodels.regression.mixed_linear_model as mlm_
#       9 import statsmodels.regression.quantile_regression as qr_
# ---> 10 import statsmodels.robust.robust_linear_model as roblm_
#      12 gls = lm_.GLS.from_formula
#      13 wls = lm_.WLS.from_formula
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\robust\__init__.py:21
#       2 __all__ = [
#       3     "CovDetMCD",
#       4     "CovDetMM",
#    (...)
#      17     "test",
#      18 ]
#      19 from statsmodels.tools._test_runner import PytestTester
# ---> 21 from . import covariance, norms, resistant_linear_model
#      22 from .covariance import CovDetMCD, CovDetMM, CovDetS, CovM
#      23 from .resistant_linear_model import RLMDetS, RLMDetSMM
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\robust\covariance.py:35
#      32 from scipy.linalg.lapack import get_lapack_funcs
#      34 import statsmodels.robust.norms as rnorms
# ---> 35 import statsmodels.robust.scale as rscale
#      36 import statsmodels.robust.tools as rtools
#      37 from statsmodels.stats.covariance import corr_normal_scores, corr_rank
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\robust\scale.py:25
#      22 from statsmodels.tools.validation import array_like, float_like, string_like
#      24 from . import norms
# ---> 25 from ._qn import _qn
#      27 GAUSSIAN_3_4 = Gaussian.ppf(3 / 4.0)
#      28 GAUSSIAN_IQR = GAUSSIAN_3_4 - Gaussian.ppf(1 / 4)
#
# ImportError: DLL load failed while importing _qn: An Application Control policy has blocked this file.

# %%
cars_data
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %% [markdown]
# ### Let's now perform Homoscedasticity Test (Test 5 and 6)

# %%
plt.scatter(data=cars_data, x="HP", y=error)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18220\2067107631.py in ?()
# ----> 1 plt.scatter(data=cars_data, x="HP", y=error)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py in ?(*args, **kwargs)
#     449                 since, message="Passing the %(name)s %(obj_type)s "
#     450                 "positionally is deprecated since Matplotlib %(since)s; the "
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py in ?(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3944     plotnonfinite: bool = False,
#    3945     data=None,
#    3946     **kwargs,
#    3947 ) -> PathCollection:
# -> 3948     __ret = gca().scatter(
#    3949         x,
#    3950         y,
#    3951         s=s,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py in ?(*args, **kwargs)
#     449                 since, message="Passing the %(name)s %(obj_type)s "
#     450                 "positionally is deprecated since Matplotlib %(since)s; the "
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py in ?(ax, data, *args, **kwargs)
#    1526                 *map(cbook.sanitize_sequence, args),
#    1527                 **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1528
#    1529         bound = new_sig.bind(ax, *args, **kwargs)
# -> 1530         auto_label = (bound.arguments.get(label_namer)
#    1531                       or bound.kwargs.get(label_namer))
#    1532
#    1533         for k, v in bound.arguments.items():
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self)
#    1578     @final
#    1579     def __nonzero__(self) -> NoReturn:
# -> 1580         raise ValueError(
#    1581             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1582             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1583         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
cars_data["error"] = error

cars_data
# Out:
#      HP        MPG  VOL          SP         WT      error
# 0    49  53.700681   89  104.185353  28.762059  10.258747
# 1    55  50.013401   92  105.461264  30.466833   7.624608
# 2    55  50.013401   92  105.461264  30.193597   7.734060
# 3    70  45.696322   92  113.461264  30.632114   3.157963
# 4    53  50.504232   92  104.461264  29.889149   8.331584
# ..  ...        ...  ...         ...        ...        ...
# 76  322  36.900000   50  169.598513  16.132947  15.617904
# 77  238  19.197888  115  150.576579  37.923113   1.298838
# 78  263  34.000000   50  151.598513  15.769625   7.863547
# 79  295  19.833733  119  167.944460  39.423099   7.517122
# 80  236  12.101263  107  139.840817  34.948615  -3.458218
#
# [81 rows x 6 columns]

# %% [markdown]
# ### Pyplot chart

# %%
plt.scatter(data=cars_data, x="HP", y="error")

# %% [markdown]
# ### Pyplot should use the column within the dataset but Seaborn chart can use out side of dataset column

# %% [markdown]
# ### Seeaborn Chart

# %%
sns.scatterplot(data=cars_data, x="HP", y=error)
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %%
sns.scatterplot(data=cars_data, x="SP", y=error)
# Out:
# <Axes: xlabel='SP', ylabel='MPG'>

# %%
sns.scatterplot(data=cars_data, x="VOL", y=error)
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
sns.scatterplot(data=cars_data, x="WT", y=error)
# Out:
# <Axes: xlabel='WT', ylabel='MPG'>

# %% [markdown]
# ### Test 5 - Homoscedasticity Test alse Failed

# %% [markdown]
# ### Test 6  - Zero Residual Mean Test

# %%
sns.scatterplot(x=cars_data["MPG"], y=y_pred)

plt.show()

# %% [markdown]
# ### Test 6 - Zero Residual Mean Test is also Failed

# %% [markdown]
# ## 9. Model Deployment

# %%
from pickle import dump

# %%
dump(obj = linear_model, file=open(file="linear_intelligence_file.pkl", mode="wb"))

# %%
from pickle import load

# %%
linear_intel_pkl = load(file=open(file="linear_intelligence_file.pkl", mode="rb"))

linear_intel_pkl
# Out:
# LinearRegression()

# %%
linear_intel_pkl.predict(x)
# Out:
# array([43.44193477, 42.38879289, 42.27934147, 42.53835981, 42.17264802,
#        43.02061916, 42.32536062, 48.07621852, 48.28120247, 40.79122814,
#        41.52153227, 47.80956747, 39.95980269, 41.52757889, 41.76632332,
#        41.6181448 , 41.15094046, 47.98605515, 41.30861046, 37.87127922,
#        38.57706414, 37.35199705, 37.89770285, 39.5625144 , 39.93380662,
#        46.73870908, 35.48165898, 38.78152504, 38.24861192, 36.00285298,
#        34.84603989, 37.21630246, 37.13919796, 34.82541399, 37.22361389,
#        37.53950097, 39.27144845, 38.24219888, 38.54286458, 35.9391722 ,
#        34.2129755 , 35.36313259, 37.50473376, 38.07998482, 35.79651664,
#        36.2613377 , 34.21826465, 35.59393404, 36.91805291, 33.31108154,
#        33.21313413, 33.3023649 , 29.19864884, 27.52358579, 28.3207133 ,
#        28.56722621, 35.81583602, 33.02108459, 35.37334971, 32.29909503,
#        29.87685849, 28.76093817, 25.14188416, 26.47040896, 25.97651933,
#        36.35652478, 26.0975912 , 23.6416178 , 24.39887199, 20.21195358,
#        27.80846468, 22.44206834, 23.07667801, 18.717314  , 23.84934696,
#        21.07461275, 21.28209598, 17.89904991, 26.13645315, 12.31661154,
#        15.55948057])
